# %% [markdown]
# # Task 3

# %% [markdown]
# # Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# Author: Shikha Pathak

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataf = pd.read_csv("globalt.csv", encoding ='latin1')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dataf.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
dataf.shape
# Out:
# (181691, 135)

# %%
dataf.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
dataf.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
dataf.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
corrdf = dataf.corr()
corrdf
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
df = dataf.rename(columns= {'iyear':'Year','imonth':'Month', 'iday':'day','extended':'Extended','country_txt':'Country', 'provstate':'State','region_txt':'Region', 'city':'City','latitude':'Latitude','longitude':'Longitude','attacktype1_txt':'Attacktype', 'nkill':'Killed', 'nwound':'wounded', 'target1':'Target','summary':'Summary', 'gname':'Group','weaptype1_txt':'Weapontype' ,'motive':'Motive','targtype1_txt':'Targettype'})

# %%
df =df[['Year','Month', 'day','Extended','Country', 'State','Region', 'City','Latitude','Longitude','Attacktype','Killed', 'wounded','Target','Summary', 'Group','Weapontype' ,'Motive','Targettype']]

# %%
df.head()
# Out:
#    Year  Month  day  Extended             Country    State  \
# 0  1970      7    2         0  Dominican Republic      NaN
# 1  1970      0    0         0              Mexico  Federal
# 2  1970      1    0         0         Philippines   Tarlac
# 3  1970      1    0         0              Greece   Attica
# 4  1970      1    0         0               Japan  Fukouka
#
#                         Region           City   Latitude   Longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
#
#                        Attacktype  Killed  wounded                   Target  \
# 0                   Assassination     1.0      0.0             Julio Guzman
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   day         181691 non-null  int64
#  3   Extended    181691 non-null  int64
#  4   Country     181691 non-null  object
#  5   State       181270 non-null  object
#  6   Region      181691 non-null  object
#  7   City        181257 non-null  object
#  8   Latitude    177135 non-null  float64
#  9   Longitude   177134 non-null  float64
#  10  Attacktype  181691 non-null  object
#  11  Killed      171378 non-null  float64
#  12  wounded     165380 non-null  float64
#  13  Target      181055 non-null  object
#  14  Summary     115562 non-null  object
#  15  Group       181691 non-null  object
#  16  Weapontype  181691 non-null  object
#  17  Motive      50561 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Extended           0
# Country            0
# State            421
# Region             0
# City             434
# Latitude        4556
# Longitude       4557
# Attacktype         0
# Killed         10313
# wounded        16311
# Target           636
# Summary        66129
# Group              0
# Weapontype         0
# Motive        131130
# Targettype         0
# dtype: int64

# %%
df.describe()
# Out:
#                 Year          Month            day       Extended  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644       0.045346
# std        13.259430       3.388303       8.814045       0.208063
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       0.000000
# max      2017.000000      12.000000      31.000000       1.000000
#
#             Latitude     Longitude         Killed        wounded
# count  177135.000000  1.771340e+05  171378.000000  165380.000000
# mean       23.498343 -4.586957e+02       2.403272       3.167668
# std        18.569242  2.047790e+05      11.545741      35.949392
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# ...

# %%
print('most attacked country: ', df['Country'].value_counts().idxmax())
print('most of the time type of attacks: ', df['Attacktype'].value_counts().idxmax())
print('Year in which most of the attack occured: ', df['Year'].value_counts().idxmax())
print('most attacked city:', df['City'].value_counts().index[1])
print('most attacked Region: ', df['Region'].value_counts().idxmax())
print('most attacked group: ', df['Group'].value_counts().idxmax())
print('month in which most of the attack occured: ', df['Month'].value_counts().idxmax())
# Out:
# most attacked country:  Iraq
# most of the time type of attacks:  Bombing/Explosion
# Year in which most of the attack occured:  2014
# most attacked city: Baghdad
# most attacked Region:  Middle East & North Africa
# most attacked group:  Unknown
# month in which most of the attack occured:  5

# %%
sns.heatmap(df.corr(), vmin= -1, vmax =1, cmap= sns.diverging_palette(20,220,as_cmap= True))
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(20,10))
sns.countplot(df['Year'],palette="rocket_r")
plt.title('Terriorist activity each year')
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
TerrorRe = pd.crosstab(df.Year, df.Region)
TerrorRe.plot(kind = 'area',color = sns.color_palette('husl',12))
fig= plt.gcf()
fig.set_size_inches(20,10)
plt.show()

# %%
df['wounded'] =df['wounded'].fillna(0).astype(int) #History of the Worst Terror Attacks in Heatmap using Plotly
df['Killed'] = df['Killed'].fillna(0).astype(int)
df['casualities'] = df['Killed'] + df['wounded']

# %%
df1 = df.sort_values(by='casualities',ascending=False)[:40] #Values are sorted by the top 40 worst terror attacks as to keep the heatmap simple and easy to visualize

# %%
heat=df1.pivot_table(index='Country',columns='Year',values='casualities')
heat.fillna(0,inplace=True)

# %%
df.Country.value_counts()[:15]
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Name: Country, dtype: int64

# %%
plt.subplots(figsize=(15,6)) #Top Countries affected by Terror Attacks
sns.barplot(df['Country'].value_counts()[:15].index,df['Country'].value_counts()[:15].values,palette='Blues_d')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ter_df =df[(df['Group'] != 'Unknown') & (df['casualities'] > 50)]
ter_df.head()
# Out:
#       Year  Month  day  Extended         Country             State  \
# 1200  1972      3    4         0  United Kingdom  Northern Ireland
# 1314  1972      5   30         0          Israel           Central
# 1789  1973      3    8         0  United Kingdom           England
# 1972  1973      8    5         0          Greece            Attica
# 2138  1973     12   17         1           Italy             Lazio
#
#                           Region     City   Latitude  Longitude  \
# 1200              Western Europe  Belfast  54.607712  -5.956210
# 1314  Middle East & North Africa      Lod  32.004361  34.888229
# 1789              Western Europe   London  51.504387  -0.140041
# 1972              Western Europe   Athens  37.997490  23.762728
# 2138              Western Europe     Rome  41.890961  12.490069
#
#                                Attacktype  Killed  wounded  \
# 1200                    Bombing/Explosion       2      130
# ...

# %%
plt.figure(figsize=(13,6)) #Methods of attack
sns.countplot(df['Attacktype'],data=df,order=df['Attacktype'].value_counts().index, palette='mako')
plt.xticks(rotation=90)
plt.xlabel('Method')
plt.title('Method of Attack')
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,axes = plt.subplots(figsize=(16,11),nrows=1,ncols=2) #Country and region
sns.barplot(x = df['Country'].value_counts()[:20].values, y = df['Country'].value_counts()[:20].index,ax=axes[0],palette = 'mako');
axes[0].set_title('Terrorist Attacks per Country')
sns.barplot(x=df['Region'].value_counts().values,y=df['Region'].value_counts().index, ax=axes[1])
axes[1].set_title('Terrorist Attacks per Region')
fig.tight_layout()
plt.show()

# %%
plt.subplots(figsize=(11,10)) #Most active organisations
sns.barplot(y=df['Group'].value_counts()[1:12].index,x=df['Group'].value_counts()[1:12].values,palette='rocket_r')
plt.title('Most Active Terrorist Organizations')
plt.show()

# %%
#Before and after the War on Terror

#After the 9/11 attacks in New York City, the US-led War on Terror was launched with the goal to distinguish terrorism primarily in the Middle East. 
#Here, it is shown as a turning point for activity patterns in each region.

df_after = df[df['Year']>=2001]
fig,ax = plt.subplots(figsize=(15,10),nrows=2,ncols=1)
ax[0] = pd.crosstab(df.Year,df.Region).plot(ax=ax[0])
ax[0].set_title('Change in Regions per Year')
ax[0].legend(loc='center left',bbox_to_anchor = (1,0.5))
ax[0].vlines(x=2001,ymin=0,ymax=7000,colors='red',linestyles='--')
pd.crosstab(df_after.Year,df_after.Region).plot.bar(stacked=True,ax=ax[1])
ax[1].set_title('After Declaration of War on Terror (2001-2017)')
ax[1].legend(loc='center left',bbox_to_anchor = (1,0.5))
plt.show()
